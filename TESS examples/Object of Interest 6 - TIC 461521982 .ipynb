# %%
# %matplotlib inline

# %%
import lightkurve as lk

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
search_ffi = lk.search_tesscut('TIC 461521982')

# %%
search_ffi
# Out:
# SearchResult containing 10 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 TESS Sector 19 2019 TESScut    1426 TIC 461521982      0.0
#   1 TESS Sector 20 2019 TESScut    1426 TIC 461521982      0.0
#   2 TESS Sector 25 2020 TESScut    1426 TIC 461521982      0.0
#   3 TESS Sector 26 2020 TESScut    1426 TIC 461521982      0.0
#   4 TESS Sector 40 2021 TESScut     475 TIC 461521982      0.0
#   5 TESS Sector 47 2021 TESScut     475 TIC 461521982      0.0
#   6 TESS Sector 52 2022 TESScut     475 TIC 461521982      0.0
#   7 TESS Sector 53 2022 TESScut     475 TIC 461521982      0.0
#   8 TESS Sector 59 2022 TESScut     158 TIC 461521982      0.0
#   9 TESS Sector 60 2022 TESScut     158 TIC 461521982      0.0

# %%
search_tpf = lk.search_targetpixelfile('TIC 461521982')

# %%
search_tpf
# Out:
# SearchResult containing 16 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 19 2019      SPOC     120   461521982      0.0
#   1 TESS Sector 19 2019 TESS-SPOC    1800   461521982      0.0
#   2 TESS Sector 20 2019      SPOC     120   461521982      0.0
#   3 TESS Sector 20 2019 TESS-SPOC    1800   461521982      0.0
#   4 TESS Sector 25 2020      SPOC     120   461521982      0.0
#   5 TESS Sector 25 2020 TESS-SPOC    1800   461521982      0.0
#   6 TESS Sector 26 2020      SPOC     120   461521982      0.0
#   7 TESS Sector 26 2020 TESS-SPOC    1800   461521982      0.0
#   8 TESS Sector 40 2021      SPOC     120   461521982      0.0
#   9 TESS Sector 40 2021 TESS-SPOC     600   461521982      0.0
#  10 TESS Sector 47 2021      SPOC     120   461521982      0.0
#  11 TESS Sector 47 2021 TESS-SPOC     600   461521982      0.0
#  12 TESS Sector 52 2022      SPOC     120   461521982      0.0
#  13 TESS Sector 53 2022      SPOC     120   461521982      0.0
#  14 TESS Sector 60 2022      SPOC      20   461521982      0.0
#  15 TESS Sector 60 2022      SPOC     120   461521982      0.0

# %%
search_lcf = lk.search_lightcurve('TIC 461521982')

# %%
search_lcf
# Out:
# SearchResult containing 25 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 19 2019      SPOC     120   461521982      0.0
#   1 TESS Sector 19 2019 TESS-SPOC    1800   461521982      0.0
#   2 TESS Sector 19 2019       QLP    1800   461521982      0.0
#   3 TESS Sector 20 2019      SPOC     120   461521982      0.0
#   4 TESS Sector 20 2019 TESS-SPOC    1800   461521982      0.0
#   5 TESS Sector 20 2019       QLP    1800   461521982      0.0
#   6 TESS Sector 25 2020      SPOC     120   461521982      0.0
#   7 TESS Sector 25 2020 TESS-SPOC    1800   461521982      0.0
#   8 TESS Sector 25 2020       QLP    1800   461521982      0.0
#   9 TESS Sector 26 2020      SPOC     120   461521982      0.0
# ...            ...  ...       ...     ...         ...      ...
#  15 TESS Sector 40 2021      SPOC     120   461521982      0.0
#  16 TESS Sector 40 2021 TESS-SPOC     600   461521982      0.0
#  17 TESS Sector 40 2021       QLP     600   461521982      0.0
#  18 TESS Sector 47 2021      SPOC     120   461521982      0.0
#  19 TESS Sector 47 2021 TESS-SPOC     600   461521982      0.0
#  20 TESS Sector 47 2021       QLP     600   461521982      0.0
#  21 TESS Sector 52 2022      SPOC     120   461521982      0.0
#  22 TESS Sector 53 2022      SPOC     120   461521982      0.0
#  23 TESS Sector 60 2022      SPOC      20   461521982      0.0
#  24 TESS Sector 60 2022      SPOC     120   461521982      0.0
# Length = 25 rows

# %%
search_lcf_refined = lk.search_lightcurve('TIC 461521982', author="SPOC", exptime=120)

# %%
search_lcf_refined
# Out:
# SearchResult containing 9 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 19 2019   SPOC     120   461521982      0.0
#   1 TESS Sector 20 2019   SPOC     120   461521982      0.0
#   2 TESS Sector 25 2020   SPOC     120   461521982      0.0
#   3 TESS Sector 26 2020   SPOC     120   461521982      0.0
#   4 TESS Sector 40 2021   SPOC     120   461521982      0.0
#   5 TESS Sector 47 2021   SPOC     120   461521982      0.0
#   6 TESS Sector 52 2022   SPOC     120   461521982      0.0
#   7 TESS Sector 53 2022   SPOC     120   461521982      0.0
#   8 TESS Sector 60 2022   SPOC     120   461521982      0.0

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 9 objects:
#     0: <TessLightCurve LABEL="TIC 461521982" SECTOR=19 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 461521982" SECTOR=20 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 461521982" SECTOR=25 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 461521982" SECTOR=26 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 461521982" SECTOR=40 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 461521982" SECTOR=47 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 461521982" SECTOR=52 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 461521982" SECTOR=53 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 461521982" SECTOR=60 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lcf[0]
# Out:
# <TessLightCurve length=17065 LABEL="TIC 461521982" SECTOR=19 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1816.0865058065071  9.1395094e+04 ...  6.5418831e-03  1.9175144e-02
# 1816.0878947150686  9.1459227e+04 ...  5.9833401e-03  1.5634684e-02
#  1816.089283623863  9.1380594e+04 ...  5.4930858e-03  1.7690809e-02
#  1816.090672532426  9.1461078e+04 ...  7.1913642e-03  1.9362666e-02
# 1816.0920614412216  9.1456469e+04 ...  3.6638449e-03  1.3005308e-02
#  1816.093450349783  9.1435914e+04 ...  5.0667264e-03  1.8781589e-02
# 1816.0948392583448  9.1507484e+04 ...  3.4194076e-03  1.6645906e-02
# 1816.0962281671405  9.1435992e+04 ...  1.0786510e-02  1.7417047e-02
# 1816.0976170757033  9.1530188e+04 ...  4.1923993e-03  1.8966790e-02
#                ...            ... ...            ...            ...
# 1841.1380102862104            ——— ...  4.3642838e-03 -7.4512370e-02
#  1841.139399171024            ——— ...  5.4660956e-03 -7.4249841e-02
# 1841.1407880560703            ——— ...  5.8700643e-03 -7.6790631e-02
# 1841.1421769408828            ——— ...  7.2436281e-03 -7.3219031e-02
# 1841.1435658256971            ——— ...  4.5722793e-03 -7.4747741e-02
# 1841.1449547105115            ——— ...  5.6735696e-03 -7.1941920e-02
# 1841.1463435955568            ——— ...  7.1696332e-03 -7.5364590e-02
# 1841.1477324803705            ——— ...            ———            ———
#  1841.149121365184            ——— ...            ———            ———
# 1841.1505102502304            ——— ...            ———            ———

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %%
ax = lcf[0].plot() 
ax.set_title("PDCSAP light curve of TIC 1981834582")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of TIC 1981834582')

# %%
flat_lc = lcf[0].flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=9.777)
folded_lc.plot();

# %%
binned_lc = folded_lc.bin(time_bin_size=0.01)
binned_lc.plot();

# %%
lcf[0].flatten(window_length=401).fold(period=9.777).bin(time_bin_size=0.01).plot();

# %%
lcf[0].interact_bls()
# Out:
# <script id="1002">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57535/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:57535&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data = search_ffi[1].download(cutout_size=20)

# %%
ffi_data.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: TIC 461521982, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# 24

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1183 LABEL="" SECTOR=20>
#        time             flux          flux_err     ... cadenceno quality
#                     electron / s    electron / s   ...
#        Time           float32         float32      ...   int32    int32
# ------------------ ------------- ----------------- ... --------- -------
#  1842.533447265625 86863.6015625 8.340340614318848 ...         0       0
# 1842.5542602539062  86882.734375 8.340315818786621 ...         1       0
# 1842.5751342773438 86802.5859375  8.33774471282959 ...         2       0
#  1842.595947265625    86861.4375 8.338881492614746 ...         3       0
# 1842.6167602539062 86810.4921875  8.33765697479248 ...         4       0
# 1842.6376342773438   86826.21875 8.338273048400879 ...         5       0
#  1842.658447265625 86797.2890625 8.336966514587402 ...         6       0
# 1842.6792602539062  86877.859375  8.33985424041748 ...         7       0
# 1842.7001342773438  86850.171875 8.339406967163086 ...         8       0
#                ...           ...               ... ...       ...     ...
# 1868.6165161132812 86865.1484375 8.339482307434082 ...      1173       0
# 1868.6373291015625 86855.5703125 8.341143608093262 ...      1174       0
# 1868.6581420898438 86935.3359375 8.340510368347168 ...      1175       0
# 1868.6790161132812  86922.171875 8.341715812683105 ...      1176       0
# 1868.6998291015625 86949.2578125 8.345163345336914 ...      1177       0
# 1868.7206420898438 86949.3984375 8.342341423034668 ...      1178       0
# 1868.7415161132812 86959.5234375 8.342215538024902 ...      1179       0
# 1868.7623291015625 86983.3828125  8.34421157836914 ...      1180       0
# 1868.7831420898438 86950.5078125 8.340947151184082 ...      1181       0
# 1868.8040161132812 86966.4453125 8.342469215393066 ...      1182       0

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
ffi_data.interact()
# Out:
# <script id="1003">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57541/autoload.js?bokeh-autoload-element=1003&bokeh-absolute-url=http://localhost:57541&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data.interact_sky()
# Out:
# <script id="1004">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:57543/autoload.js?bokeh-autoload-element=1004&bokeh-absolute-url=http://localhost:57543&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.6, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}' .format(best_fit_period))
# Out:
# Best fit period: 9.777 d
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:545: LightkurveWarning: interact_sky() - cannot obtain nearby TICs. Skip it. The error: not enough values to unpack (expected 3, got 2)
#   warnings.warn(
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:631: LightkurveWarning: Proper motion correction cannot be applied to the target, as none is available. Thus the target (the cross) might be noticeably away from its actual position, if it has large proper motion.
#   warnings.warn(("Proper motion correction cannot be applied to the target, as none is available. "
