# %%
# %matplotlib inline

# %%
import lightkurve as lk

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
search_ffi = lk.search_tesscut('TIC 353894978')

# %%
search_ffi
# Out:
# SearchResult containing 29 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 TESS Sector 14 2019 TESScut    1426 TIC 353894978      0.0
#   1 TESS Sector 15 2019 TESScut    1426 TIC 353894978      0.0
#   2 TESS Sector 16 2019 TESScut    1426 TIC 353894978      0.0
#   3 TESS Sector 17 2019 TESScut    1426 TIC 353894978      0.0
#   4 TESS Sector 18 2019 TESScut    1426 TIC 353894978      0.0
#   5 TESS Sector 19 2019 TESScut    1426 TIC 353894978      0.0
#   6 TESS Sector 20 2019 TESScut    1426 TIC 353894978      0.0
#   7 TESS Sector 21 2020 TESScut    1426 TIC 353894978      0.0
#   8 TESS Sector 22 2020 TESScut    1426 TIC 353894978      0.0
#   9 TESS Sector 23 2020 TESScut    1426 TIC 353894978      0.0
# ...            ...  ...     ...     ...           ...      ...
#  19 TESS Sector 51 2022 TESScut     475 TIC 353894978      0.0
#  20 TESS Sector 52 2022 TESScut     475 TIC 353894978      0.0
#  21 TESS Sector 53 2022 TESScut     475 TIC 353894978      0.0
#  22 TESS Sector 54 2022 TESScut     475 TIC 353894978      0.0
#  23 TESS Sector 55 2022 TESScut     475 TIC 353894978      0.0
#  24 TESS Sector 56 2022 TESScut     158 TIC 353894978      0.0
#  25 TESS Sector 57 2022 TESScut     158 TIC 353894978      0.0
#  26 TESS Sector 58 2022 TESScut     158 TIC 353894978      0.0
#  27 TESS Sector 59 2022 TESScut     158 TIC 353894978      0.0
#  28 TESS Sector 60 2022 TESScut     158 TIC 353894978      0.0
# Length = 29 rows

# %%
search_tpf = lk.search_targetpixelfile('TIC 353894978')

# %%
search_tpf
# Out:
# SearchResult containing 46 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   353894978      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   353894978      0.0
#   2 TESS Sector 15 2019      SPOC     120   353894978      0.0
#   3 TESS Sector 15 2019 TESS-SPOC    1800   353894978      0.0
#   4 TESS Sector 16 2019      SPOC     120   353894978      0.0
#   5 TESS Sector 16 2019 TESS-SPOC    1800   353894978      0.0
#   6 TESS Sector 17 2019      SPOC     120   353894978      0.0
#   7 TESS Sector 17 2019 TESS-SPOC    1800   353894978      0.0
#   8 TESS Sector 18 2019      SPOC     120   353894978      0.0
#   9 TESS Sector 18 2019 TESS-SPOC    1800   353894978      0.0
# ...            ...  ...       ...     ...         ...      ...
#  36 TESS Sector 50 2022      SPOC     120   353894978      0.0
#  37 TESS Sector 51 2022      SPOC     120   353894978      0.0
#  38 TESS Sector 52 2022      SPOC     120   353894978      0.0
#  39 TESS Sector 54 2022      SPOC     120   353894978      0.0
#  40 TESS Sector 55 2022      SPOC     120   353894978      0.0
#  41 TESS Sector 56 2022      SPOC     120   353894978      0.0
#  42 TESS Sector 57 2022      SPOC     120   353894978      0.0
#  43 TESS Sector 58 2022      SPOC     120   353894978      0.0
#  44 TESS Sector 59 2022      SPOC     120   353894978      0.0
#  45 TESS Sector 60 2022      SPOC     120   353894978      0.0
# Length = 46 rows

# %%
search_lcf = lk.search_lightcurve('TIC 353894978')

# %%
search_lcf
# Out:
# SearchResult containing 73 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   353894978      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   353894978      0.0
#   2 TESS Sector 14 2019       QLP    1800   353894978      0.0
#   3 TESS Sector 14 2019     TASOC     120   353894978      0.0
#   4 TESS Sector 14 2019     TASOC    1800   353894978      0.0
#   5 TESS Sector 14 2019     TASOC    1800   353894978      0.0
#   6 TESS Sector 15 2019      SPOC     120   353894978      0.0
#   7 TESS Sector 15 2019 TESS-SPOC    1800   353894978      0.0
#   8 TESS Sector 15 2019       QLP    1800   353894978      0.0
#   9 TESS Sector 15 2019     TASOC     120   353894978      0.0
# ...            ...  ...       ...     ...         ...      ...
#  63 TESS Sector 50 2022      SPOC     120   353894978      0.0
#  64 TESS Sector 51 2022      SPOC     120   353894978      0.0
#  65 TESS Sector 52 2022      SPOC     120   353894978      0.0
#  66 TESS Sector 54 2022      SPOC     120   353894978      0.0
#  67 TESS Sector 55 2022      SPOC     120   353894978      0.0
#  68 TESS Sector 56 2022      SPOC     120   353894978      0.0
#  69 TESS Sector 57 2022      SPOC     120   353894978      0.0
#  70 TESS Sector 58 2022      SPOC     120   353894978      0.0
#  71 TESS Sector 59 2022      SPOC     120   353894978      0.0
#  72 TESS Sector 60 2022      SPOC     120   353894978      0.0
# Length = 73 rows

# %%
search_lcf_refined = lk.search_lightcurve('TIC 353894978', author="SPOC", exptime=120)

# %%
search_lcf_refined
# Out:
# SearchResult containing 28 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   353894978      0.0
#   1 TESS Sector 15 2019   SPOC     120   353894978      0.0
#   2 TESS Sector 16 2019   SPOC     120   353894978      0.0
#   3 TESS Sector 17 2019   SPOC     120   353894978      0.0
#   4 TESS Sector 18 2019   SPOC     120   353894978      0.0
#   5 TESS Sector 19 2019   SPOC     120   353894978      0.0
#   6 TESS Sector 20 2019   SPOC     120   353894978      0.0
#   7 TESS Sector 21 2020   SPOC     120   353894978      0.0
#   8 TESS Sector 22 2020   SPOC     120   353894978      0.0
#   9 TESS Sector 23 2020   SPOC     120   353894978      0.0
# ...            ...  ...    ...     ...         ...      ...
#  18 TESS Sector 50 2022   SPOC     120   353894978      0.0
#  19 TESS Sector 51 2022   SPOC     120   353894978      0.0
#  20 TESS Sector 52 2022   SPOC     120   353894978      0.0
#  21 TESS Sector 54 2022   SPOC     120   353894978      0.0
#  22 TESS Sector 55 2022   SPOC     120   353894978      0.0
#  23 TESS Sector 56 2022   SPOC     120   353894978      0.0
#  24 TESS Sector 57 2022   SPOC     120   353894978      0.0
#  25 TESS Sector 58 2022   SPOC     120   353894978      0.0
#  26 TESS Sector 59 2022   SPOC     120   353894978      0.0
#  27 TESS Sector 60 2022   SPOC     120   353894978      0.0
# Length = 28 rows

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 28 objects:
#     0: <TessLightCurve LABEL="TIC 353894978" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 353894978" SECTOR=15 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 353894978" SECTOR=16 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 353894978" SECTOR=17 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 353894978" SECTOR=18 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 353894978" SECTOR=19 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 353894978" SECTOR=20 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 353894978" SECTOR=21 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 353894978" SECTOR=22 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: <TessLightCurve LABEL="TIC 353894978" SECTOR=23 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     10: <TessLightCurve LABEL="TIC 353894978" SECTOR=24 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     11: <TessLightCurve LABEL="TIC 353894978" SECTOR=25 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     12: <TessLightCurve LABEL="TIC 353894978" SECTOR=26 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     13: <TessLightCurve LABEL="TIC 353894978" SECTOR=40 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     14: <TessLightCurve LABEL="TIC 353894978" SECTOR=41 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     15: <TessLightCurve LABEL="TIC 353894978" SECTOR=47 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     16: <TessLightCurve LABEL="TIC 353894978" SECTOR=48 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     17: <TessLightCurve LABEL="TIC 353894978" SECTOR=49 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     18: <TessLightCurve LABEL="TIC 353894978" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     19: <TessLightCurve LABEL="TIC 353894978" SECTOR=51 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     20: <TessLightCurve LABEL="TIC 353894978" SECTOR=52 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     21: <TessLightCurve LABEL="TIC 353894978" SECTOR=54 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     22: <TessLightCurve LABEL="TIC 353894978" SECTOR=55 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     23: <TessLightCurve LABEL="TIC 353894978" SECTOR=56 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     24: <TessLightCurve LABEL="TIC 353894978" SECTOR=57 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     25: <TessLightCurve LABEL="TIC 353894978" SECTOR=58 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     26: <TessLightCurve LABEL="TIC 353894978" SECTOR=59 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     27: <TessLightCurve LABEL="TIC 353894978" SECTOR=60 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lcf[0]
# Out:
# <TessLightCurve length=18424 LABEL="TIC 353894978" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1683.3548857845065  1.2050251e+04 ...  6.6125058e-03  4.7715802e-02
# 1683.3562746611035  1.2034117e+04 ...  4.7000046e-03  4.8843965e-02
# 1683.3576635376428  1.2071902e+04 ...  8.1717987e-03  5.0094068e-02
# 1683.3590524142394  1.2022963e+04 ...  9.8298173e-03  5.3437144e-02
# 1683.3604412908358  1.2053200e+04 ...  9.7377878e-03  4.5510184e-02
# 1683.3618301673748  1.2061472e+04 ...  7.3624155e-03  4.5876965e-02
# 1683.3632190439137  1.2045338e+04 ...  1.0274758e-02  5.2789349e-02
# 1683.3646079205112  1.2035646e+04 ...  9.0941889e-03  4.9151711e-02
#   1683.36599679705  1.2003811e+04 ...  1.1683751e-02  4.3894291e-02
#                ...            ... ...            ...            ...
#  1710.192118663368  1.2020126e+04 ...  1.9356310e-02 -2.7302194e-03
# 1710.1935075393242  1.2026600e+04 ...  1.9169461e-02 -9.2436103e-03
# 1710.1948964152814  1.1994904e+04 ...  1.7002270e-02 -2.9820399e-03
# 1710.1962852912964  1.2003604e+04 ...  1.6474284e-02  3.1428242e-03
# 1710.1976741672527  1.2019089e+04 ...  1.6350051e-02 -1.0257756e-02
#   1710.19906304321  1.2023505e+04 ...  1.6287860e-02 -5.3983079e-03
# 1710.2004519192258  1.2006701e+04 ...  1.3669165e-02  1.5148071e-03
# 1710.2018407951825  1.1992752e+04 ...  2.2988783e-02 -7.8603365e-03
# 1710.2032296711388  1.2017866e+04 ...  1.8710654e-02 -1.9842323e-03
# 1710.2046185470952  1.2014511e+04 ...  1.4335818e-02 -2.8916362e-03

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %%
ax = lcf[0].plot() 
ax.set_title("PDCSAP light curve of TIC 353894978")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of TIC 353894978')

# %%
flat_lc = lcf[0].flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=1.671)
folded_lc.plot();

# %%
binned_lc = folded_lc.bin(time_bin_size=0.01)
binned_lc.plot();

# %%
lcf[0].flatten(window_length=401).fold(period=1.671).bin(time_bin_size=0.01).plot();

# %%
lcf[0].interact_bls()
# Out:
# <script id="7370">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:50674/autoload.js?bokeh-autoload-element=7370&bokeh-absolute-url=http://localhost:50674&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data = search_ffi[1].download(cutout_size=10)

# %%
ffi_data.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: TIC 353894978, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# 9

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1190 LABEL="" SECTOR=15>
#        time              flux            flux_err      ... cadenceno quality
#                      electron / s      electron / s    ...
#        Time            float32           float32       ...   int32    int32
# ------------------ ---------------- ------------------ ... --------- -------
# 1711.3870239257812  9364.3271484375  2.759953498840332 ...         0       0
# 1711.4078979492188     9362.3046875  2.760770082473755 ...         1       0
#    1711.4287109375       9362.34375 2.7596614360809326 ...         2       0
# 1711.4495239257812  9363.6240234375  2.760000467300415 ...         3       0
# 1711.4703979492188  9362.4951171875 2.7600350379943848 ...         4       0
#    1711.4912109375  9360.7138671875  2.760127305984497 ...         5       0
# 1711.5120239257812  9359.7353515625  2.760068655014038 ...         6       0
# 1711.5328979492188       9355.28125 2.7599759101867676 ...         7       0
#    1711.5537109375         9357.625  2.759037733078003 ...         8       0
#                ...              ...                ... ...       ...     ...
# 1737.1992797851562 10401.8955078125 2.9006593227386475 ...      1180       0
# 1737.2200927734375 10270.9541015625  2.883758306503296 ...      1181       0
# 1737.2409057617188 10136.9580078125 2.8653597831726074 ...      1182       0
# 1737.2617797851562  10019.677734375  2.850119113922119 ...      1183       0
# 1737.2825927734375  9892.8427734375  2.833608388900757 ...      1184       0
# 1737.3034057617188   9756.060546875 2.8155930042266846 ...      1185       0
# 1737.3242797851562   9622.810546875  2.795799493789673 ...      1186       0
# 1737.3450927734375   9456.443359375 2.7731568813323975 ...      1187       0
# 1737.3659057617188  9018.0693359375  2.713352918624878 ...      1188       0
# 1737.3867797851562  8456.8095703125  2.634838342666626 ...      1189       0

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
ffi_data.interact()
# Out:
# <script id="7371">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:50679/autoload.js?bokeh-autoload-element=7371&bokeh-absolute-url=http://localhost:50679&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data.interact_sky()
# Out:
# <script id="7372">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:50681/autoload.js?bokeh-autoload-element=7372&bokeh-absolute-url=http://localhost:50681&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.6, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}' .format(best_fit_period))
# Out:
# Best fit period: 1.671 d
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:545: LightkurveWarning: interact_sky() - cannot obtain nearby TICs. Skip it. The error: not enough values to unpack (expected 3, got 2)
#   warnings.warn(
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:631: LightkurveWarning: Proper motion correction cannot be applied to the target, as none is available. Thus the target (the cross) might be noticeably away from its actual position, if it has large proper motion.
#   warnings.warn(("Proper motion correction cannot be applied to the target, as none is available. "
