# %%
# %matplotlib inline

# %%
import lightkurve as lk

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
search_ffi = lk.search_tesscut('TIC 198384408')

# %%
search_ffi
# Out:
# SearchResult containing 27 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 TESS Sector 14 2019 TESScut    1426 TIC 198384408      0.0
#   1 TESS Sector 15 2019 TESScut    1426 TIC 198384408      0.0
#   2 TESS Sector 17 2019 TESScut    1426 TIC 198384408      0.0
#   3 TESS Sector 18 2019 TESScut    1426 TIC 198384408      0.0
#   4 TESS Sector 19 2019 TESScut    1426 TIC 198384408      0.0
#   5 TESS Sector 20 2019 TESScut    1426 TIC 198384408      0.0
#   6 TESS Sector 21 2020 TESScut    1426 TIC 198384408      0.0
#   7 TESS Sector 22 2020 TESScut    1426 TIC 198384408      0.0
#   8 TESS Sector 23 2020 TESScut    1426 TIC 198384408      0.0
#   9 TESS Sector 24 2020 TESScut    1426 TIC 198384408      0.0
# ...            ...  ...     ...     ...           ...      ...
#  17 TESS Sector 50 2022 TESScut     475 TIC 198384408      0.0
#  18 TESS Sector 51 2022 TESScut     475 TIC 198384408      0.0
#  19 TESS Sector 52 2022 TESScut     475 TIC 198384408      0.0
#  20 TESS Sector 53 2022 TESScut     475 TIC 198384408      0.0
#  21 TESS Sector 54 2022 TESScut     475 TIC 198384408      0.0
#  22 TESS Sector 55 2022 TESScut     475 TIC 198384408      0.0
#  23 TESS Sector 56 2022 TESScut     158 TIC 198384408      0.0
#  24 TESS Sector 57 2022 TESScut     158 TIC 198384408      0.0
#  25 TESS Sector 59 2022 TESScut     158 TIC 198384408      0.0
#  26 TESS Sector 60 2022 TESScut     158 TIC 198384408      0.0
# Length = 27 rows

# %%
search_tpf = lk.search_targetpixelfile('TIC 198384408')

# %%
search_tpf
# Out:
# SearchResult containing 54 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   198384408      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   198384408      0.0
#   2 TESS Sector 15 2019      SPOC     120   198384408      0.0
#   3 TESS Sector 15 2019 TESS-SPOC    1800   198384408      0.0
#   4 TESS Sector 17 2019      SPOC     120   198384408      0.0
#   5 TESS Sector 17 2019 TESS-SPOC    1800   198384408      0.0
#   6 TESS Sector 18 2019      SPOC     120   198384408      0.0
#   7 TESS Sector 18 2019 TESS-SPOC    1800   198384408      0.0
#   8 TESS Sector 19 2019      SPOC     120   198384408      0.0
#   9 TESS Sector 19 2019 TESS-SPOC    1800   198384408      0.0
# ...            ...  ...       ...     ...         ...      ...
#  44 TESS Sector 54 2022      SPOC      20   198384408      0.0
#  45 TESS Sector 54 2022      SPOC     120   198384408      0.0
#  46 TESS Sector 56 2022      SPOC      20   198384408      0.0
#  47 TESS Sector 56 2022      SPOC     120   198384408      0.0
#  48 TESS Sector 57 2022      SPOC      20   198384408      0.0
#  49 TESS Sector 57 2022      SPOC     120   198384408      0.0
#  50 TESS Sector 59 2022      SPOC      20   198384408      0.0
#  51 TESS Sector 59 2022      SPOC     120   198384408      0.0
#  52 TESS Sector 60 2022      SPOC      20   198384408      0.0
#  53 TESS Sector 60 2022      SPOC     120   198384408      0.0
# Length = 54 rows

# %%
search_lcf = lk.search_lightcurve('TIC 198384408')

# %%
search_lcf
# Out:
# SearchResult containing 78 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   198384408      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   198384408      0.0
#   2 TESS Sector 14 2019       QLP    1800   198384408      0.0
#   3 TESS Sector 14 2019     TASOC     120   198384408      0.0
#   4 TESS Sector 14 2019     TASOC    1800   198384408      0.0
#   5 TESS Sector 14 2019     TASOC    1800   198384408      0.0
#   6 TESS Sector 15 2019      SPOC     120   198384408      0.0
#   7 TESS Sector 15 2019 TESS-SPOC    1800   198384408      0.0
#   8 TESS Sector 15 2019       QLP    1800   198384408      0.0
#   9 TESS Sector 15 2019     TASOC     120   198384408      0.0
# ...            ...  ...       ...     ...         ...      ...
#  68 TESS Sector 54 2022      SPOC      20   198384408      0.0
#  69 TESS Sector 54 2022      SPOC     120   198384408      0.0
#  70 TESS Sector 56 2022      SPOC      20   198384408      0.0
#  71 TESS Sector 56 2022      SPOC     120   198384408      0.0
#  72 TESS Sector 57 2022      SPOC      20   198384408      0.0
#  73 TESS Sector 57 2022      SPOC     120   198384408      0.0
#  74 TESS Sector 59 2022      SPOC      20   198384408      0.0
#  75 TESS Sector 59 2022      SPOC     120   198384408      0.0
#  76 TESS Sector 60 2022      SPOC      20   198384408      0.0
#  77 TESS Sector 60 2022      SPOC     120   198384408      0.0
# Length = 78 rows

# %%
search_lcf_refined = lk.search_lightcurve('TIC 198384408', author="SPOC", exptime=120)

# %%
search_lcf_refined
# Out:
# SearchResult containing 25 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   198384408      0.0
#   1 TESS Sector 15 2019   SPOC     120   198384408      0.0
#   2 TESS Sector 17 2019   SPOC     120   198384408      0.0
#   3 TESS Sector 18 2019   SPOC     120   198384408      0.0
#   4 TESS Sector 19 2019   SPOC     120   198384408      0.0
#   5 TESS Sector 20 2019   SPOC     120   198384408      0.0
#   6 TESS Sector 21 2020   SPOC     120   198384408      0.0
#   7 TESS Sector 22 2020   SPOC     120   198384408      0.0
#   8 TESS Sector 23 2020   SPOC     120   198384408      0.0
#   9 TESS Sector 24 2020   SPOC     120   198384408      0.0
# ...            ...  ...    ...     ...         ...      ...
#  15 TESS Sector 49 2022   SPOC     120   198384408      0.0
#  16 TESS Sector 50 2022   SPOC     120   198384408      0.0
#  17 TESS Sector 51 2022   SPOC     120   198384408      0.0
#  18 TESS Sector 52 2022   SPOC     120   198384408      0.0
#  19 TESS Sector 53 2022   SPOC     120   198384408      0.0
#  20 TESS Sector 54 2022   SPOC     120   198384408      0.0
#  21 TESS Sector 56 2022   SPOC     120   198384408      0.0
#  22 TESS Sector 57 2022   SPOC     120   198384408      0.0
#  23 TESS Sector 59 2022   SPOC     120   198384408      0.0
#  24 TESS Sector 60 2022   SPOC     120   198384408      0.0
# Length = 25 rows

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 25 objects:
#     0: <TessLightCurve LABEL="TIC 198384408" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 198384408" SECTOR=15 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 198384408" SECTOR=17 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 198384408" SECTOR=18 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 198384408" SECTOR=19 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 198384408" SECTOR=20 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 198384408" SECTOR=21 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 198384408" SECTOR=22 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 198384408" SECTOR=23 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: <TessLightCurve LABEL="TIC 198384408" SECTOR=24 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     10: <TessLightCurve LABEL="TIC 198384408" SECTOR=25 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     11: <TessLightCurve LABEL="TIC 198384408" SECTOR=26 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     12: <TessLightCurve LABEL="TIC 198384408" SECTOR=40 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     13: <TessLightCurve LABEL="TIC 198384408" SECTOR=41 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     14: <TessLightCurve LABEL="TIC 198384408" SECTOR=47 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     15: <TessLightCurve LABEL="TIC 198384408" SECTOR=49 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     16: <TessLightCurve LABEL="TIC 198384408" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     17: <TessLightCurve LABEL="TIC 198384408" SECTOR=51 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     18: <TessLightCurve LABEL="TIC 198384408" SECTOR=52 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     19: <TessLightCurve LABEL="TIC 198384408" SECTOR=53 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     20: <TessLightCurve LABEL="TIC 198384408" SECTOR=54 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     21: <TessLightCurve LABEL="TIC 198384408" SECTOR=56 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     22: <TessLightCurve LABEL="TIC 198384408" SECTOR=57 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     23: <TessLightCurve LABEL="TIC 198384408" SECTOR=59 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     24: <TessLightCurve LABEL="TIC 198384408" SECTOR=60 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lcf[0]
# Out:
# <TessLightCurve length=18424 LABEL="TIC 198384408" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1683.3544566814778  4.7392831e+05 ... -1.2444209e-02 -2.8024979e-02
# 1683.3558455425334  4.7392103e+05 ... -1.0825287e-02 -3.0380465e-02
# 1683.3572344035895  4.7405291e+05 ... -1.5826503e-02 -3.0978490e-02
# 1683.3586232646446  4.7416150e+05 ... -1.6537350e-02 -3.5866994e-02
# 1683.3600121256995  4.7433822e+05 ... -1.5619094e-02 -2.5607245e-02
# 1683.3614009867554  4.7388738e+05 ... -1.4208764e-02 -2.9390203e-02
#  1683.362789847811  4.7408122e+05 ... -1.8002532e-02 -3.6941838e-02
# 1683.3641787088088  4.7391712e+05 ... -1.5709737e-02 -3.1936333e-02
# 1683.3655675698644  4.7346516e+05 ... -1.8032178e-02 -2.6377806e-02
#                ...            ... ...            ...            ...
# 1710.1914475194176  4.7335291e+05 ... -1.8280944e-02 -2.3048371e-02
# 1710.1928363846307  4.7330453e+05 ... -1.8857583e-02 -1.5977183e-02
# 1710.1942252498377  4.7356106e+05 ... -1.3989922e-02 -2.1550426e-02
# 1710.1956141150406  4.7347744e+05 ... -1.6943056e-02 -2.9307097e-02
# 1710.1970029802394  4.7354028e+05 ... -1.5799139e-02 -1.2120406e-02
# 1710.1983918454355  4.7356384e+05 ... -1.5564682e-02 -1.8221328e-02
# 1710.1997807106284  4.7334128e+05 ... -1.3438308e-02 -2.4211697e-02
# 1710.2011695758167  4.7370534e+05 ... -1.9302391e-02 -1.4176078e-02
# 1710.2025584410046  4.7326084e+05 ... -1.6947316e-02 -1.9468999e-02
# 1710.2039473061852  4.7339625e+05 ... -1.2313645e-02 -1.6817009e-02

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %%
ax = lcf[0].plot() 
ax.set_title("PDCSAP light curve of ")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of ')

# %%
flat_lc = lcf[0].flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=5.662)
folded_lc.plot();

# %%
binned_lc = folded_lc.bin(time_bin_size=0.01)
binned_lc.plot();

# %%
lcf[0].flatten(window_length=401).fold(period=5.662).bin(time_bin_size=0.01).plot();

# %%
lcf[0].interact_bls()
# Out:
# <script id="6167">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:61147/autoload.js?bokeh-autoload-element=6167&bokeh-absolute-url=http://localhost:61147&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data = search_ffi[1].download(cutout_size=10)

# %%
ffi_data.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: TIC 198384408, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# 13

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1190 LABEL="" SECTOR=15>
#        time            flux          flux_err      ... cadenceno quality
#                    electron / s    electron / s    ...
#        Time          float32         float32       ...   int32    int32
# ------------------ ------------ ------------------ ... --------- -------
# 1711.3859252929688    409880.25 17.529644012451172 ...         0       0
#   1711.40673828125  409771.0625 17.527387619018555 ...         1       0
# 1711.4275512695312  409654.6875 17.524873733520508 ...         2       0
# 1711.4484252929688   409705.125  17.52715492248535 ...         3       0
#   1711.46923828125 409694.84375  17.52667808532715 ...         4       0
# 1711.4900512695312 409560.90625  17.52332878112793 ...         5       0
# 1711.5109252929688 409411.34375 17.520366668701172 ...         6       0
#   1711.53173828125 409137.84375  17.51390838623047 ...         7       0
# 1711.5525512695312 409468.40625 17.522144317626953 ...         8       0
#                ...          ...                ... ...       ...     ...
# 1737.1981201171875 411380.09375 17.561960220336914 ...      1180       0
# 1737.2189331054688 411305.46875 17.561172485351562 ...      1181       0
# 1737.2398071289062 411049.34375 17.555334091186523 ...      1182       0
# 1737.2606201171875 411162.96875 17.557518005371094 ...      1183       0
# 1737.2814331054688 411042.65625  17.55494499206543 ...      1184       0
# 1737.3023071289062  410935.5625 17.552547454833984 ...      1185       0
# 1737.3231201171875  410786.1875 17.549419403076172 ...      1186       0
# 1737.3439331054688    410800.25 17.550491333007812 ...      1187       0
# 1737.3648071289062   410705.375  17.54796600341797 ...      1188       0
# 1737.3856201171875   410584.875 17.544998168945312 ...      1189       0

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
ffi_data.interact()
# Out:
# <script id="6168">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:61153/autoload.js?bokeh-autoload-element=6168&bokeh-absolute-url=http://localhost:61153&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data.interact_sky()
# Out:
# <script id="6169">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:61155/autoload.js?bokeh-autoload-element=6169&bokeh-absolute-url=http://localhost:61155&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.6, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}' .format(best_fit_period))
# Out:
# Best fit period: 5.662 d
# ERROR:tornado.application:Uncaught exception GET /autoload.js?bokeh-autoload-element=6169&bokeh-absolute-url=http://localhost:61155&resources=none (::1)
# HTTPServerRequest(protocol='http', host='localhost:61155', method='GET', uri='/autoload.js?bokeh-autoload-element=6169&bokeh-absolute-url=http://localhost:61155&resources=none', version='HTTP/1.1', remote_ip='::1')
# Traceback (most recent call last):
#   File "C:\Users\andre\anaconda3\lib\site-packages\tornado\web.py", line 1704, in _execute
#     result = await result
#   File "C:\Users\andre\anaconda3\lib\site-packages\bokeh\server\views\autoload_js_handler.py", line 62, in get
#     session = await self.get_session()
#   File "C:\Users\andre\anaconda3\lib\site-packages\bokeh\server\views\session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "C:\Users\andre\anaconda3\lib\site-packages\bokeh\server\contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "C:\Users\andre\anaconda3\lib\site-packages\bokeh\application\application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "C:\Users\andre\anaconda3\lib\site-packages\bokeh\application\handlers\function.py", line 143, in modify_document
#     self._func(doc)
#   File "C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py", line 1362, in create_interact_ui
#     fig_tpf, r, message_selected_target = add_gaia_figure_elements(
#   File "C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py", line 538, in add_gaia_figure_elements
#     result = _get_nearby_gaia_objects(tpf, magnitude_limit)
#   File "C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py", line 524, in _get_nearby_gaia_objects
#     raise too_few_found_message
# ValueError: No sources found brighter than 18.0
# ERROR:tornado.access:500 GET /autoload.js?bokeh-autoload-element=6169&bokeh-absolute-url=http://localhost:61155&resources=none (::1) 36.86ms
