# %%
# %matplotlib inline

# %%
import lightkurve as lk

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
search_ffi = lk.search_tesscut('TIC 219109908')

# %%
search_ffi
# Out:
# SearchResult containing 28 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 TESS Sector 14 2019 TESScut    1426 TIC 219109908      0.0
#   1 TESS Sector 15 2019 TESScut    1426 TIC 219109908      0.0
#   2 TESS Sector 16 2019 TESScut    1426 TIC 219109908      0.0
#   3 TESS Sector 17 2019 TESScut    1426 TIC 219109908      0.0
#   4 TESS Sector 18 2019 TESScut    1426 TIC 219109908      0.0
#   5 TESS Sector 19 2019 TESScut    1426 TIC 219109908      0.0
#   6 TESS Sector 20 2019 TESScut    1426 TIC 219109908      0.0
#   7 TESS Sector 21 2020 TESScut    1426 TIC 219109908      0.0
#   8 TESS Sector 22 2020 TESScut    1426 TIC 219109908      0.0
#   9 TESS Sector 23 2020 TESScut    1426 TIC 219109908      0.0
# ...            ...  ...     ...     ...           ...      ...
#  18 TESS Sector 51 2022 TESScut     475 TIC 219109908      0.0
#  19 TESS Sector 52 2022 TESScut     475 TIC 219109908      0.0
#  20 TESS Sector 53 2022 TESScut     475 TIC 219109908      0.0
#  21 TESS Sector 54 2022 TESScut     475 TIC 219109908      0.0
#  22 TESS Sector 55 2022 TESScut     475 TIC 219109908      0.0
#  23 TESS Sector 56 2022 TESScut     158 TIC 219109908      0.0
#  24 TESS Sector 57 2022 TESScut     158 TIC 219109908      0.0
#  25 TESS Sector 58 2022 TESScut     158 TIC 219109908      0.0
#  26 TESS Sector 59 2022 TESScut     158 TIC 219109908      0.0
#  27 TESS Sector 60 2022 TESScut     158 TIC 219109908      0.0
# Length = 28 rows

# %%
search_tpf = lk.search_targetpixelfile('TIC 219109908')

# %%
search_tpf
# Out:
# SearchResult containing 43 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   219109908      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   219109908      0.0
#   2 TESS Sector 15 2019      SPOC     120   219109908      0.0
#   3 TESS Sector 15 2019 TESS-SPOC    1800   219109908      0.0
#   4 TESS Sector 16 2019      SPOC     120   219109908      0.0
#   5 TESS Sector 16 2019 TESS-SPOC    1800   219109908      0.0
#   6 TESS Sector 17 2019      SPOC     120   219109908      0.0
#   7 TESS Sector 17 2019 TESS-SPOC    1800   219109908      0.0
#   8 TESS Sector 18 2019      SPOC     120   219109908      0.0
#   9 TESS Sector 18 2019 TESS-SPOC    1800   219109908      0.0
# ...            ...  ...       ...     ...         ...      ...
#  33 TESS Sector 51 2022      SPOC     120   219109908      0.0
#  34 TESS Sector 52 2022      SPOC     120   219109908      0.0
#  35 TESS Sector 53 2022      SPOC     120   219109908      0.0
#  36 TESS Sector 54 2022      SPOC     120   219109908      0.0
#  37 TESS Sector 55 2022      SPOC     120   219109908      0.0
#  38 TESS Sector 56 2022      SPOC     120   219109908      0.0
#  39 TESS Sector 57 2022      SPOC     120   219109908      0.0
#  40 TESS Sector 58 2022      SPOC     120   219109908      0.0
#  41 TESS Sector 59 2022      SPOC     120   219109908      0.0
#  42 TESS Sector 60 2022      SPOC     120   219109908      0.0
# Length = 43 rows

# %%
search_lcf = lk.search_lightcurve('TIC 219109908')

# %%
search_lcf
# Out:
# SearchResult containing 68 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   219109908      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   219109908      0.0
#   2 TESS Sector 14 2019       QLP    1800   219109908      0.0
#   3 TESS Sector 14 2019     TASOC     120   219109908      0.0
#   4 TESS Sector 14 2019     TASOC    1800   219109908      0.0
#   5 TESS Sector 14 2019     TASOC    1800   219109908      0.0
#   6 TESS Sector 15 2019      SPOC     120   219109908      0.0
#   7 TESS Sector 15 2019 TESS-SPOC    1800   219109908      0.0
#   8 TESS Sector 15 2019       QLP    1800   219109908      0.0
#   9 TESS Sector 15 2019     TASOC     120   219109908      0.0
# ...            ...  ...       ...     ...         ...      ...
#  58 TESS Sector 51 2022      SPOC     120   219109908      0.0
#  59 TESS Sector 52 2022      SPOC     120   219109908      0.0
#  60 TESS Sector 53 2022      SPOC     120   219109908      0.0
#  61 TESS Sector 54 2022      SPOC     120   219109908      0.0
#  62 TESS Sector 55 2022      SPOC     120   219109908      0.0
#  63 TESS Sector 56 2022      SPOC     120   219109908      0.0
#  64 TESS Sector 57 2022      SPOC     120   219109908      0.0
#  65 TESS Sector 58 2022      SPOC     120   219109908      0.0
#  66 TESS Sector 59 2022      SPOC     120   219109908      0.0
#  67 TESS Sector 60 2022      SPOC     120   219109908      0.0
# Length = 68 rows

# %%
search_lcf_refined = lk.search_lightcurve('TIC 219109908', author="SPOC", exptime=120)

# %%
search_lcf_refined
# Out:
# SearchResult containing 27 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   219109908      0.0
#   1 TESS Sector 15 2019   SPOC     120   219109908      0.0
#   2 TESS Sector 16 2019   SPOC     120   219109908      0.0
#   3 TESS Sector 17 2019   SPOC     120   219109908      0.0
#   4 TESS Sector 18 2019   SPOC     120   219109908      0.0
#   5 TESS Sector 20 2019   SPOC     120   219109908      0.0
#   6 TESS Sector 21 2020   SPOC     120   219109908      0.0
#   7 TESS Sector 22 2020   SPOC     120   219109908      0.0
#   8 TESS Sector 23 2020   SPOC     120   219109908      0.0
#   9 TESS Sector 24 2020   SPOC     120   219109908      0.0
# ...            ...  ...    ...     ...         ...      ...
#  17 TESS Sector 51 2022   SPOC     120   219109908      0.0
#  18 TESS Sector 52 2022   SPOC     120   219109908      0.0
#  19 TESS Sector 53 2022   SPOC     120   219109908      0.0
#  20 TESS Sector 54 2022   SPOC     120   219109908      0.0
#  21 TESS Sector 55 2022   SPOC     120   219109908      0.0
#  22 TESS Sector 56 2022   SPOC     120   219109908      0.0
#  23 TESS Sector 57 2022   SPOC     120   219109908      0.0
#  24 TESS Sector 58 2022   SPOC     120   219109908      0.0
#  25 TESS Sector 59 2022   SPOC     120   219109908      0.0
#  26 TESS Sector 60 2022   SPOC     120   219109908      0.0
# Length = 27 rows

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 27 objects:
#     0: <TessLightCurve LABEL="TIC 219109908" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 219109908" SECTOR=15 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 219109908" SECTOR=16 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 219109908" SECTOR=17 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 219109908" SECTOR=18 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 219109908" SECTOR=20 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 219109908" SECTOR=21 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 219109908" SECTOR=22 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 219109908" SECTOR=23 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: <TessLightCurve LABEL="TIC 219109908" SECTOR=24 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     10: <TessLightCurve LABEL="TIC 219109908" SECTOR=25 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     11: <TessLightCurve LABEL="TIC 219109908" SECTOR=26 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     12: <TessLightCurve LABEL="TIC 219109908" SECTOR=40 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     13: <TessLightCurve LABEL="TIC 219109908" SECTOR=41 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     14: <TessLightCurve LABEL="TIC 219109908" SECTOR=47 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     15: <TessLightCurve LABEL="TIC 219109908" SECTOR=48 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     16: <TessLightCurve LABEL="TIC 219109908" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     17: <TessLightCurve LABEL="TIC 219109908" SECTOR=51 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     18: <TessLightCurve LABEL="TIC 219109908" SECTOR=52 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     19: <TessLightCurve LABEL="TIC 219109908" SECTOR=53 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     20: <TessLightCurve LABEL="TIC 219109908" SECTOR=54 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     21: <TessLightCurve LABEL="TIC 219109908" SECTOR=55 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     22: <TessLightCurve LABEL="TIC 219109908" SECTOR=56 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     23: <TessLightCurve LABEL="TIC 219109908" SECTOR=57 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     24: <TessLightCurve LABEL="TIC 219109908" SECTOR=58 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     25: <TessLightCurve LABEL="TIC 219109908" SECTOR=59 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     26: <TessLightCurve LABEL="TIC 219109908" SECTOR=60 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lcf[0]
# Out:
# <TessLightCurve length=18424 LABEL="TIC 219109908" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
#  1683.353637986118  5.7919771e+03 ... -3.1045771e-03 -2.4118494e-02
# 1683.3550268773834  5.7103115e+03 ... -1.7424808e-03 -2.5143979e-02
# 1683.3564157686783  5.5477681e+03 ... -6.0908478e-03 -2.6382582e-02
# 1683.3578046599432  5.4527271e+03 ... -7.0664203e-03 -3.0120080e-02
#  1683.359193551208  5.3439893e+03 ... -5.3761085e-03 -2.2096470e-02
# 1683.3605824424444  5.2484312e+03 ... -4.9750097e-03 -2.4742905e-02
# 1683.3619713337098  5.1879194e+03 ... -8.0253016e-03 -3.0772097e-02
# 1683.3633602249756  5.0683584e+03 ... -5.7169776e-03 -2.7552646e-02
#  1683.364749116241  5.0261084e+03 ... -7.6405755e-03 -2.2766830e-02
#                ...            ... ...            ...            ...
#   1710.19123301813  9.1332568e+03 ...  4.5306622e-03 -2.0946497e-02
#  1710.192621917442  9.1727725e+03 ...  4.8027341e-03 -1.5898278e-02
# 1710.1940108167405  9.2080088e+03 ...  9.2511028e-03 -2.0841818e-02
# 1710.1953997160385  9.2305791e+03 ...  5.0538685e-03 -2.5494335e-02
# 1710.1967886153507  9.2654658e+03 ...  7.9711843e-03 -1.2658737e-02
# 1710.1981775146492  9.2513887e+03 ...  7.3528024e-03 -1.7332854e-02
# 1710.1995664139627  9.2400332e+03 ...  8.7262616e-03 -2.2021020e-02
# 1710.2009553132752  9.2781924e+03 ...  4.5206859e-03 -1.5050618e-02
# 1710.2023442125728  9.2844629e+03 ...  6.3121142e-03 -1.8614747e-02
#  1710.203733111885  9.2726895e+03 ...  1.0871423e-02 -1.7523589e-02

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %%
ax = lcf[0].plot() 
ax.set_title("PDCSAP light curve of TIC 219109908")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of TIC 219428571')

# %%
flat_lc = lcf[0].flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=0.636)
folded_lc.plot();

# %%
binned_lc = folded_lc.bin(time_bin_size=0.01)
binned_lc.plot();

# %%
lcf[0].flatten(window_length=401).fold(period=0.636).bin(time_bin_size=0.01).plot();

# %%
lcf[0].interact_bls()
# Out:
# <script id="8886">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:63765/autoload.js?bokeh-autoload-element=8886&bokeh-absolute-url=http://localhost:63765&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data = search_ffi[1].download(cutout_size=10)

# %%
ffi_data.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: TIC 219109908, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# 10

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1190 LABEL="" SECTOR=15>
#        time              flux            flux_err      ... cadenceno quality
#                      electron / s      electron / s    ...
#        Time            float32           float32       ...   int32    int32
# ------------------ ---------------- ------------------ ... --------- -------
# 1711.3856201171875   12321.87890625 3.3454477787017822 ...         0       0
# 1711.4064331054688 13482.8447265625 3.4689297676086426 ...         1       0
# 1711.4273071289062 14583.7744140625 3.5856411457061768 ...         2       0
# 1711.4481201171875     15274.515625  3.655047655105591 ...         3       0
# 1711.4689331054688 15645.0205078125 3.6968796253204346 ...         4       0
# 1711.4898071289062 15564.6240234375 3.6861793994903564 ...         5       0
# 1711.5106201171875 15030.4580078125  3.630937337875366 ...         6       0
# 1711.5314331054688 14170.7607421875 3.5420124530792236 ...         7       0
# 1711.5523071289062 12959.5146484375 3.4131834506988525 ...         8       0
#                ...              ...                ... ...       ...     ...
# 1737.1984252929688  14184.509765625 3.5442612171173096 ...      1180       0
#   1737.21923828125  12997.611328125 3.4195022583007812 ...      1181       0
# 1737.2400512695312 12775.7548828125 3.3948161602020264 ...      1182       0
# 1737.2609252929688    13206.6953125 3.4445583820343018 ...      1183       0
#   1737.28173828125   14435.12890625  3.570251941680908 ...      1184       0
# 1737.3025512695312  15218.095703125  3.649775505065918 ...      1185       0
# 1737.3234252929688 15707.4130859375  3.700963020324707 ...      1186       0
#   1737.34423828125 15848.3154296875 3.7139956951141357 ...      1187       0
# 1737.3650512695312 15533.3154296875   3.68292498588562 ...      1188       0
# 1737.3859252929688 14830.2060546875  3.609419107437134 ...      1189       0

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
ffi_data.interact()
# Out:
# <script id="8887">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:63771/autoload.js?bokeh-autoload-element=8887&bokeh-absolute-url=http://localhost:63771&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data.interact_sky()
# Out:
# <script id="8888">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:63773/autoload.js?bokeh-autoload-element=8888&bokeh-absolute-url=http://localhost:63773&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.6, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}' .format(best_fit_period))
# Out:
# Best fit period: 0.636 d
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:545: LightkurveWarning: interact_sky() - cannot obtain nearby TICs. Skip it. The error: not enough values to unpack (expected 3, got 2)
#   warnings.warn(
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:631: LightkurveWarning: Proper motion correction cannot be applied to the target, as none is available. Thus the target (the cross) might be noticeably away from its actual position, if it has large proper motion.
#   warnings.warn(("Proper motion correction cannot be applied to the target, as none is available. "
