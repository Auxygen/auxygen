# %%
# %matplotlib inline

# %%
import lightkurve as lk

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
search_ffi = lk.search_tesscut('TIC 237114978')

# %%
search_ffi
# Out:
# SearchResult containing 29 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 TESS Sector 14 2019 TESScut    1426 TIC 237114978      0.0
#   1 TESS Sector 15 2019 TESScut    1426 TIC 237114978      0.0
#   2 TESS Sector 16 2019 TESScut    1426 TIC 237114978      0.0
#   3 TESS Sector 17 2019 TESScut    1426 TIC 237114978      0.0
#   4 TESS Sector 18 2019 TESScut    1426 TIC 237114978      0.0
#   5 TESS Sector 19 2019 TESScut    1426 TIC 237114978      0.0
#   6 TESS Sector 20 2019 TESScut    1426 TIC 237114978      0.0
#   7 TESS Sector 21 2020 TESScut    1426 TIC 237114978      0.0
#   8 TESS Sector 22 2020 TESScut    1426 TIC 237114978      0.0
#   9 TESS Sector 23 2020 TESScut    1426 TIC 237114978      0.0
# ...            ...  ...     ...     ...           ...      ...
#  19 TESS Sector 51 2022 TESScut     475 TIC 237114978      0.0
#  20 TESS Sector 52 2022 TESScut     475 TIC 237114978      0.0
#  21 TESS Sector 53 2022 TESScut     475 TIC 237114978      0.0
#  22 TESS Sector 54 2022 TESScut     475 TIC 237114978      0.0
#  23 TESS Sector 55 2022 TESScut     475 TIC 237114978      0.0
#  24 TESS Sector 56 2022 TESScut     158 TIC 237114978      0.0
#  25 TESS Sector 57 2022 TESScut     158 TIC 237114978      0.0
#  26 TESS Sector 58 2022 TESScut     158 TIC 237114978      0.0
#  27 TESS Sector 59 2022 TESScut     158 TIC 237114978      0.0
#  28 TESS Sector 60 2022 TESScut     158 TIC 237114978      0.0
# Length = 29 rows

# %%
search_tpf = lk.search_targetpixelfile('TIC 237114978')

# %%
search_tpf
# Out:
# SearchResult containing 36 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   237114978      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   237114978      0.0
#   2 TESS Sector 15 2019 TESS-SPOC    1800   237114978      0.0
#   3 TESS Sector 16 2019 TESS-SPOC    1800   237114978      0.0
#   4 TESS Sector 17 2019 TESS-SPOC    1800   237114978      0.0
#   5 TESS Sector 18 2019 TESS-SPOC    1800   237114978      0.0
#   6 TESS Sector 19 2019 TESS-SPOC    1800   237114978      0.0
#   7 TESS Sector 20 2019 TESS-SPOC    1800   237114978      0.0
#   8 TESS Sector 21 2020 TESS-SPOC    1800   237114978      0.0
#   9 TESS Sector 22 2020 TESS-SPOC    1800   237114978      0.0
# ...            ...  ...       ...     ...         ...      ...
#  26 TESS Sector 51 2022      SPOC     120   237114978      0.0
#  27 TESS Sector 52 2022      SPOC     120   237114978      0.0
#  28 TESS Sector 53 2022      SPOC     120   237114978      0.0
#  29 TESS Sector 54 2022      SPOC     120   237114978      0.0
#  30 TESS Sector 55 2022      SPOC     120   237114978      0.0
#  31 TESS Sector 56 2022      SPOC     120   237114978      0.0
#  32 TESS Sector 57 2022      SPOC     120   237114978      0.0
#  33 TESS Sector 58 2022      SPOC     120   237114978      0.0
#  34 TESS Sector 59 2022      SPOC     120   237114978      0.0
#  35 TESS Sector 60 2022      SPOC     120   237114978      0.0
# Length = 36 rows

# %%
search_lcf = lk.search_lightcurve('TIC 237114978')

# %%
search_lcf
# Out:
# SearchResult containing 58 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120   237114978      0.0
#   1 TESS Sector 14 2019 TESS-SPOC    1800   237114978      0.0
#   2 TESS Sector 14 2019       QLP    1800   237114978      0.0
#   3 TESS Sector 14 2019     TASOC     120   237114978      0.0
#   4 TESS Sector 14 2019     TASOC    1800   237114978      0.0
#   5 TESS Sector 14 2019     TASOC    1800   237114978      0.0
#   6 TESS Sector 15 2019 TESS-SPOC    1800   237114978      0.0
#   7 TESS Sector 15 2019       QLP    1800   237114978      0.0
#   8 TESS Sector 15 2019     TASOC    1800   237114978      0.0
#   9 TESS Sector 15 2019     TASOC    1800   237114978      0.0
# ...            ...  ...       ...     ...         ...      ...
#  48 TESS Sector 51 2022      SPOC     120   237114978      0.0
#  49 TESS Sector 52 2022      SPOC     120   237114978      0.0
#  50 TESS Sector 53 2022      SPOC     120   237114978      0.0
#  51 TESS Sector 54 2022      SPOC     120   237114978      0.0
#  52 TESS Sector 55 2022      SPOC     120   237114978      0.0
#  53 TESS Sector 56 2022      SPOC     120   237114978      0.0
#  54 TESS Sector 57 2022      SPOC     120   237114978      0.0
#  55 TESS Sector 58 2022      SPOC     120   237114978      0.0
#  56 TESS Sector 59 2022      SPOC     120   237114978      0.0
#  57 TESS Sector 60 2022      SPOC     120   237114978      0.0
# Length = 58 rows

# %%
search_lcf_refined = lk.search_lightcurve('TIC 237114978', author="SPOC", exptime=120)

# %%
search_lcf_refined
# Out:
# SearchResult containing 19 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   237114978      0.0
#   1 TESS Sector 24 2020   SPOC     120   237114978      0.0
#   2 TESS Sector 25 2020   SPOC     120   237114978      0.0
#   3 TESS Sector 40 2021   SPOC     120   237114978      0.0
#   4 TESS Sector 41 2021   SPOC     120   237114978      0.0
#   5 TESS Sector 47 2021   SPOC     120   237114978      0.0
#   6 TESS Sector 48 2022   SPOC     120   237114978      0.0
#   7 TESS Sector 49 2022   SPOC     120   237114978      0.0
#   8 TESS Sector 50 2022   SPOC     120   237114978      0.0
#   9 TESS Sector 51 2022   SPOC     120   237114978      0.0
#  10 TESS Sector 52 2022   SPOC     120   237114978      0.0
#  11 TESS Sector 53 2022   SPOC     120   237114978      0.0
#  12 TESS Sector 54 2022   SPOC     120   237114978      0.0
#  13 TESS Sector 55 2022   SPOC     120   237114978      0.0
#  14 TESS Sector 56 2022   SPOC     120   237114978      0.0
#  15 TESS Sector 57 2022   SPOC     120   237114978      0.0
#  16 TESS Sector 58 2022   SPOC     120   237114978      0.0
#  17 TESS Sector 59 2022   SPOC     120   237114978      0.0
#  18 TESS Sector 60 2022   SPOC     120   237114978      0.0

# %%
lcf = search_lcf_refined.download_all()

# %%
lcf
# Out:
# LightCurveCollection of 19 objects:
#     0: <TessLightCurve LABEL="TIC 237114978" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 237114978" SECTOR=24 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 237114978" SECTOR=25 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 237114978" SECTOR=40 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     4: <TessLightCurve LABEL="TIC 237114978" SECTOR=41 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     5: <TessLightCurve LABEL="TIC 237114978" SECTOR=47 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     6: <TessLightCurve LABEL="TIC 237114978" SECTOR=48 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     7: <TessLightCurve LABEL="TIC 237114978" SECTOR=49 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     8: <TessLightCurve LABEL="TIC 237114978" SECTOR=50 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     9: <TessLightCurve LABEL="TIC 237114978" SECTOR=51 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     10: <TessLightCurve LABEL="TIC 237114978" SECTOR=52 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     11: <TessLightCurve LABEL="TIC 237114978" SECTOR=53 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     12: <TessLightCurve LABEL="TIC 237114978" SECTOR=54 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     13: <TessLightCurve LABEL="TIC 237114978" SECTOR=55 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     14: <TessLightCurve LABEL="TIC 237114978" SECTOR=56 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     15: <TessLightCurve LABEL="TIC 237114978" SECTOR=57 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     16: <TessLightCurve LABEL="TIC 237114978" SECTOR=58 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     17: <TessLightCurve LABEL="TIC 237114978" SECTOR=59 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     18: <TessLightCurve LABEL="TIC 237114978" SECTOR=60 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lcf[0]
# Out:
# <TessLightCurve length=18424 LABEL="TIC 237114978" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1683.3546795070918  8.4851436e+03 ...  4.3858155e-03  4.8096497e-02
# 1683.3560683832814  8.4797656e+03 ...  2.8123416e-03  4.9151562e-02
# 1683.3574572594714  8.4755557e+03 ...  5.9059490e-03  5.0356932e-02
# 1683.3588461356605  8.4522988e+03 ...  7.4155498e-03  5.4235287e-02
# 1683.3602350118495  8.4374688e+03 ...  7.3283631e-03  4.6224602e-02
#  1683.361623887981  8.4163955e+03 ...  4.9038227e-03  4.6357255e-02
# 1683.3630127641707  8.3990615e+03 ...  7.9569742e-03  5.3233676e-02
# 1683.3644016403607  8.3897861e+03 ...  6.5474766e-03  4.9557880e-02
# 1683.3657905165503  8.3763740e+03 ...  9.4915526e-03  4.4383515e-02
#                ...            ... ...            ...            ...
# 1710.1919223988934  8.6422412e+03 ...  1.7851653e-02 -4.9007144e-03
# 1710.1933112761883  8.6722061e+03 ...  1.7527385e-02 -1.1389244e-02
# 1710.1947001534843  8.6787812e+03 ...  1.5344325e-02 -5.0569992e-03
# 1710.1960890307798  8.6765879e+03 ...  1.5414626e-02  1.5340091e-03
# 1710.1974779081331  8.6920020e+03 ...  1.4677898e-02 -1.2164097e-02
# 1710.1988667854291  8.7187725e+03 ...  1.4873573e-02 -7.6651005e-03
# 1710.2002556627256  8.7103750e+03 ...  1.2443947e-02 -4.3283455e-04
#  1710.201644540021  8.7142607e+03 ...  2.1187197e-02 -9.8763593e-03
# 1710.2030334173162  8.7128594e+03 ...  1.7073125e-02 -3.7953546e-03
# 1710.2044222946113  8.7293613e+03 ...  1.3131375e-02 -5.1708026e-03

# %%
ax = lcf[0].plot(column='sap_flux', normalize=True, label="SAP");
lcf[0].plot(ax=ax, column='pdcsap_flux', normalize=True, label="PDCSAP");

# %%
ax = lcf[0].plot() 
ax.set_title("PDCSAP light curve of TIC 237114978")
# Out:
# Text(0.5, 1.0, 'PDCSAP light curve of TIC 237114978')

# %%
flat_lc = lcf[0].flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=0.648)
folded_lc.plot();

# %%
binned_lc = folded_lc.bin(time_bin_size=0.01)
binned_lc.plot();

# %%
lcf[0].flatten(window_length=401).fold(period=0.648).bin(time_bin_size=0.01).plot();

# %%
lcf[0].interact_bls()
# Out:
# <script id="1002">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65330/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:65330&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data = search_ffi[1].download(cutout_size=10)

# %%
ffi_data.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: TIC 237114978, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
target_mask = ffi_data.create_threshold_mask(threshold=15, reference_pixel='center')
n_target_pixels = target_mask.sum()
n_target_pixels
# Out:
# 13

# %%
ffi_data.plot(aperture_mask=target_mask, mask_color='r');

# %%
ffi_lc = ffi_data.to_lightcurve(aperture_mask=target_mask)

# %%
ffi_lc
# Out:
# <TessLightCurve length=1190 LABEL="" SECTOR=15>
#        time              flux            flux_err      ... cadenceno quality
#                      electron / s      electron / s    ...
#        Time            float32           float32       ...   int32    int32
# ------------------ ---------------- ------------------ ... --------- -------
# 1711.3859252929688 8182.87841796875  2.879408836364746 ...         0       0
#   1711.40673828125 7954.97412109375 2.8494648933410645 ...         1       0
# 1711.4275512695312    7866.45703125  2.839446544647217 ...         2       0
# 1711.4484252929688 7994.41845703125 2.8578388690948486 ...         3       0
#   1711.46923828125   8240.669921875  2.895705223083496 ...         4       0
# 1711.4900512695312  8456.9130859375 2.9200408458709717 ...         5       0
# 1711.5109252929688   8492.337890625  2.920809507369995 ...         6       0
#   1711.53173828125  8334.0029296875 2.8989224433898926 ...         7       0
# 1711.5525512695312  8088.7744140625 2.8744421005249023 ...         8       0
#                ...              ...                ... ...       ...     ...
# 1737.1981201171875  8685.5986328125 2.9481558799743652 ...      1180       0
# 1737.2189331054688      8795.703125  2.961369276046753 ...      1181       0
# 1737.2398071289062  8939.2666015625  2.977510929107666 ...      1182       0
# 1737.2606201171875     9023.0234375 2.9878625869750977 ...      1183       0
# 1737.2814331054688  8922.6240234375 2.9770309925079346 ...      1184       0
# 1737.3023071289062   8624.634765625 2.9381744861602783 ...      1185       0
# 1737.3231201171875   8271.056640625  2.890568971633911 ...      1186       0
# 1737.3439331054688   8002.142578125  2.857495069503784 ...      1187       0
# 1737.3648071289062       7948.46875  2.849318027496338 ...      1188       0
# 1737.3856201171875 8081.30810546875 2.8680219650268555 ...      1189       0

# %%
ffi_lc.plot(label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
ax = lcf[0].plot(column='pdcsap_flux', normalize=True, label="PDCSAP");
ffi_lc.plot(ax=ax, normalize=True, label="SAP FFI")
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
ffi_data.interact()
# Out:
# <script id="1003">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65335/autoload.js?bokeh-autoload-element=1003&bokeh-absolute-url=http://localhost:65335&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
ffi_data.interact_sky()
# Out:
# <script id="1004">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:65337/autoload.js?bokeh-autoload-element=1004&bokeh-absolute-url=http://localhost:65337&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.6, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}' .format(best_fit_period))
# Out:
# Best fit period: 0.648 d
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:545: LightkurveWarning: interact_sky() - cannot obtain nearby TICs. Skip it. The error: not enough values to unpack (expected 3, got 2)
#   warnings.warn(
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# C:\Users\andre\anaconda3\lib\site-packages\lightkurve\interact.py:631: LightkurveWarning: Proper motion correction cannot be applied to the target, as none is available. Thus the target (the cross) might be noticeably away from its actual position, if it has large proper motion.
#   warnings.warn(("Proper motion correction cannot be applied to the target, as none is available. "
